# %%
import pandas as pd

# Creating DataFrame from a dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Los Angeles', 'Chicago']}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df['Age']  # Selects the Age column
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df = pd.read_xlsx('D_WEDDING.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_xlsx('D_WEDDING.xlsx')
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
#Here are the tools and code for each task:

#Task 1: Load and Explore the Dataset

#Tool: Python, Pandas, Jupyter Notebook


import pandas as pd
from sklearn.datasets import load_iris

#Load Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target

#Display first few rows
print(df.head())

#Check data types and missing values
print(df.info())
print(df.isnull().sum())


#Task 2: Basic Data Analysis

#Tool: Python, Pandas, NumPy, Jupyter Notebook


import numpy as np

#Basic data analysis
print(df.describe())

#Group by species and compute mean of sepal length
species_means = df.groupby('species')['sepal length (cm)'].mean()
print(species_means)


#Task 3: Data Visualization

#Tool: Python, Matplotlib, Seaborn, Jupyter Notebook


import matplotlib.pyplot as plt
import seaborn as sns

#Line chart
plt.figure(figsize=(8, 6))
sns.lineplot(x=np.arange(len(df)), y=df['sepal length (cm)'])
plt.title('Sepal Length over Index')
plt.xlabel('Index')
plt.ylabel('Sepal Length (cm)')
plt.show()

#Bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x='species', y='petal length (cm)', data=df)
plt.title('Average Petal Length per Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()

#Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['sepal width (cm)'], bins=10)
plt.title('Sepal Width Distribution')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.show()

#Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='sepal length (cm)', y='petal length (cm)', hue='species', data=df)
plt.title('Sepal Length vs. Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.show()


#Error Handling

#Tool: Python's built-in try-except blocks


try:
    # Load dataset
    df = pd.read_csv('dataset.csv')
except FileNotFoundError:
    print("File not found.")
except pd.errors.EmptyDataError:
    print("Dataset is empty.")
except pd.errors.ParserError:
    print("Error parsing dataset.")
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# ...
